# %% [markdown]
# ---
# title: "Iris Data Analysis"
# format:
#   revealjs:
#     theme: default
#     transition: slide
# bibliography: ../reference.bib
# ---
#
# ## Introduction to Iris Dataset
#
# - Famous dataset in data science
# - 150 flower samples
# - 3 species: setosa, versicolor, virginica
# - 4 measurements per flower
#
# ![Iris flower](images/iris_photo.jpg)
#
# ## Dataset Features
#
# - Sepal length (cm)
# - Sepal width (cm)
# - Petal length (cm)
# - Petal width (cm)
#
# ![Iris measurements](images/iris_table.png)
#
# ## Data Analysis Results
#
# Key findings:
#
# - Strong correlation between petal features
# - Species show distinct patterns
# - Perfect for classification tasks
#
# Data science methods help reveal these patterns [@cao2017data].

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
import pandas as pd

# Load iris data
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

# Simple scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='petal length (cm)', y='petal width (cm)', 
                hue='species', s=80, alpha=0.8)
plt.title('Iris Petal Measurements')
plt.show()

# %% [markdown]
# ## Navigation
#
# [Back to Main_Page](../index.qmd)
